# %%
import pandas as pd

# %%
c = pd.read_csv('cayenne.csv')
c
# Out:
#                Ng10  Ng18  Ng8  Bd12  Ng20  Ng6  Ng7  AnchoTallo  AltoTallo  \
# 1 1 4 4 2 2 2     2     1    1     2     2    0    0        1.52         78
#             2     2     1    1     2     2    0    0        1.36         74
#     3 3 2 2 2     2     1    1     2     2    2    2        1.43         69
#     4 4 2 2 2     2     1    1     2     2    2    2        1.53         68
#             2     2     1    1     2     2    2    2        1.34         84
#     3 3 2 2 2     2     1    1     2     2    2    2        1.32         72
#     4 4 2 2 2     2     1    1     2     2    4    4        1.61         87
#             2     2     1    1     2     2    4    4        1.50         72
#     3 3 2 2 2     2     1    1     2     2    2    2        1.66         94
#     4 4 2 2 2     2     1    1     2     2    2    2        1.72         49
#             2     2     1    1     2     2    2    2        1.25         61
# ...
