# %%
import pandas as pd

# %%
df = pd.read_csv('./mice/Mice_Phenotipic.csv')
df
# Out:
#      SUBJECT.NAME PROJECT.NAME PHENOTYPE.NAME  Obesity.BMI  \
# 0      A048005080     HS_mouse        Obesity    -0.520132
# 1      A048006063     HS_mouse        Obesity    -0.401116
# 2      A048006555     HS_mouse        Obesity    -0.526935
# 3      A048007096     HS_mouse        Obesity    -0.415274
# 4      A048010273     HS_mouse        Obesity    -0.546143
# ...           ...          ...            ...          ...
# 1809   A084291618     HS_mouse        Obesity    -0.397314
# 1810   A084291628     HS_mouse        Obesity    -0.498030
# 1811   A084291785     HS_mouse        Obesity    -0.363735
# 1812   A084291787     HS_mouse        Obesity    -0.398266
# 1813   A084292044     HS_mouse        Obesity    -0.445751
#
#       Obesity.BodyLength  Date.Month  Date.Year Date.Season  \
# 0                    8.2           5       2003      spring
# 1                    8.2           3       2003      spring
# 2                    8.1           4       2003      spring
# ...

# %%
mor = mor = df[['SUBJECT.NAME', 'Obesity.BodyLength']]
mor
# Out:
#      SUBJECT.NAME  Obesity.BodyLength
# 0      A048005080                 8.2
# 1      A048006063                 8.2
# 2      A048006555                 8.1
# 3      A048007096                 7.6
# 4      A048010273                 7.8
# ...           ...                 ...
# 1809   A084291618                 7.9
# 1810   A084291628                 8.8
# 1811   A084291785                 8.2
# 1812   A084291787                 7.3
# 1813   A084292044                 8.6
#
# [1814 rows x 2 columns]

# %%
mor.to_csv('./mice/mice_traits.csv', index=None)
